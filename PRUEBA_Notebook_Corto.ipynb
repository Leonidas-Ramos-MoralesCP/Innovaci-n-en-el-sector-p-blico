# %% [markdown]
# # Innovación Pública: Ejemplo Práctico
#
# **Dr. Leonidas Ramos Morales**
#
# Este es un ejemplo simple de cómo se vería un Jupyter Notebook con imágenes en GitHub.

# %% [markdown]
# ## Portada del Curso

# %% [markdown]
# ![Portada](image/png;base64,...)

# %% [markdown]
# ## Datos del Caso QuimoBike

# %%
import pandas as pd

# Datos del caso QuimoBike
datos = {
    'Métrica': ['Tiempo de uso', 'Completitud sesión', 'Ansiedad (reducida)'],
    'Antes': ['5 minutos', '55%', '7.2/10'],
    'Después': ['45 minutos', '92%', '2.8/10'],
    'Mejora': ['+800%', '+67%', '-61%']
}

df = pd.DataFrame(datos)
print("\n📊 RESULTADOS QUIMOBIKE")
print("=" * 70)
print(df.to_string(index=False))
print("\n✅ Problema resuelto con innovación pública")

# %% [markdown]
# ## Conclusión
#
# La innovación en el sector público requiere:
# - **Empatía** con los usuarios
# - **Prototipado rápido** (no esperar perfección)
# - **Validación con datos** (no intuición)
# - **Iteración** (pivotar cuando sea necesario)
#
# > *Con S/. 420 y 6 semanas, transformamos un problema en una solución.*
